# %%
import os
import random
Hangmanpics = ['''
  +---+
  |   |
      |
      |
      |
      |
=========''','''
  +---+
  |   |
  O   |
      |
      |
      |
=========''','''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========''','''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''','''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========''','''
  +---+
  |   |
  O   |
 /|\  |
   \  |
      |
=========''','''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========''']

#Create a wordlist to randomly choose from
wordList = "edition mercury jupiter saturn uranium silver science quantum conservation fedora cloud universe english rabbit mongoose parrot pigeon tortoise".split(' ')
# wordList = ['fedora']

def getWord(wordList):
    #get a random number as the index in wordList
    randIndex = random.randint(0, len(wordList)-1)
    return randIndex

def displayBoard(Hangmanpics, word, failed_guesses, correct_guesses):
    #display the current status of Hangman and the word
    print(Hangmanpics[len(failed_guesses)])
    hidden = '_' * len(word)
    currentWord = word
    for x in range(0,len(word)):
        if word[x] not in correct_guesses:
            currentWord = currentWord.replace(word[x], '_')
    print(currentWord)
    if currentWord == word:
        print("Y O U W O N!",">>The correct word is ", word)
        playAgain = str(input("Play Again? Type 'yes' or 'no': "))
        if playAgain != 'yes':
            print("Not Play Again")
            quit()
#             break
        else: main()
            
def main():
    print("Hangman")
    randIndex = getWord(wordList)
    word = str(wordList[randIndex])
#     print("Word: ",word)
    failed_guesses = ''
    correct_guesses = ''
    displayBoard(Hangmanpics, word, failed_guesses, correct_guesses)
    guess = ''
    playAgain = 'yes'
    while(True):
        guess = str(input("Enter your guess: "))
        while(len(guess) != 1 or (guess.isalpha() == False)):
            guess = str(input("Invalid, enter a single letter: "))
        if (len(failed_guesses) >= 6):
            displayBoard(Hangmanpics, word, failed_guesses, correct_guesses)
            print("Y o u L O S E!", ">>The correct word is", word)
            playAgain = str(input("Play Again? Type 'yes' or 'no': "))
            if playAgain != 'yes':
                print("Not Play Again")
                os.quit()
            else: main()
        elif (guess in word):
            print("Guess in Word")
            correct_guesses += guess
            displayBoard(Hangmanpics, word, failed_guesses, correct_guesses)
        else:
            print("Guess not in Word")
            failed_guesses += guess
            displayBoard(Hangmanpics, word, failed_guesses, correct_guesses)

main()
# Out:
# Hangman
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# ______
# Enter your guess: e
# Guess in Word
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# _e____
# Enter your guess: a
# Guess in Word
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# _e___a
# Enter your guess: t
# Guess not in Word
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# _e___a
# Enter your guess: f
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# fe___a
# Enter your guess: d
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# fed__a
# Enter your guess: o
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# fedo_a
# Enter your guess: r
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# fedora
# Y O U W O N! >>The correct word is  fedora
# Play Again? Type 'yes' or 'no': y
# Not Play Again
# Enter your guess: a
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# fedora
# Y O U W O N! >>The correct word is  fedora
# Play Again? Type 'yes' or 'no': yes
# Hangman
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# ________
# Enter your guess: p
# Guess not in Word
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# ________
# Enter your guess: a
# Guess not in Word
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# ________
# Enter your guess: u
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# u_______
# Enter your guess: r
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# u____r__
# Enter your guess: e
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# u___er_e
# Enter your guess: n
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# un__er_e
# Enter your guess: i
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# uni_er_e
# Enter your guess: c
# Guess not in Word
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# uni_er_e
# Enter your guess: v
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# univer_e
# Enter your guess: s
# Guess in Word
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# universe
# Y O U W O N! >>The correct word is  universe
# Play Again? Type 'yes' or 'no':
# Not Play Again
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 112>()
#     109             failed_guesses += guess
#     110             displayBoard(Hangmanpics, word, failed_guesses, correct_guesses)
# --> 112 main()
#
# Input In [3], in main()
#     104     print("Guess in Word")
#     105     correct_guesses += guess
# --> 106     displayBoard(Hangmanpics, word, failed_guesses, correct_guesses)
#     107 else:
#     108     print("Guess not in Word")
#
# Input In [3], in displayBoard(Hangmanpics, word, failed_guesses, correct_guesses)
#      77             quit()
#      78 #             break
# ---> 79         else: main()
#
# Input In [3], in main()
#      90 playAgain = 'yes'
#      91 while(True):
# ---> 92     guess = str(input("Enter your guess: "))
#      93     while(len(guess) != 1 or (guess.isalpha() == False)):
#      94         guess = str(input("Invalid, enter a single letter: "))
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
